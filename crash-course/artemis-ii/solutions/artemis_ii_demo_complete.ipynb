# %% [markdown]
# # **PyIU Python Crash Course (Solutions)**
# ## Last updated July 9, 2026
# ### Authors: Robert Howard, Daniel Gallego, Ryan LoRusso, Sarah Popp
#
# <br>
#
# ## **Science Topic:** The Artemis II Mission
#
# The overarching goal of NASA's [Artemis](https://www.nasa.gov/humans-in-space/artemis/) program is to establish a permanent human presence on the Moon and prepare for a crewed mission to Mars. To accomplish this, NASA is proceeding in several careful steps, the second of which was the [Artemis II](https://www.nasa.gov/mission/artemis-ii/) mission. Artemis II was a crewed test of NASA's capability to send a vessel to the Moon and back, ensuring that all the hardware, software, and support teams functioned as expected. Fortunately, they did!
#
# ### The Astronauts
#
# There were four astronauts on the Artemis II mission. Clockwise from left in the official crew portrait are:
#
# - Christina Koch (NASA): Mission Specialist 1
# - Victor Glover (NASA): Pilot
# - Jeremy Hansen (CSA): Mission Specialist 2
# - Reid Wiseman (NASA): Commander
#
# <center><img src="https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/imgs/artemis_ii_crew.jpg" width="300" alt="Official crew portrait for Artemis II, clockwise from left: NASA Astronauts Christina Koch, Victor Glover, Canadian Space Agency Astronaut Jeremy Hansen, NASA Astronaut Reid Wiseman. Image credit: https://en.wikipedia.org/wiki/File:Artemis_2_Crew_Portrait.jpg"/></center>
#
# ### The Launch
#
# Artemis II launched from NASA's Kennedy Space Center in Florida on April 1, 2026, at 6:35 pm EDT. The diagram below shows many key steps of the rocket's journey to outer space, and see [here](https://www.esa.int/esatv/Videos/2026/04/European_Service_Module_Artemis_II/April_2026_Artemis_II_Launch_-_Close_up_View) for a video of the launch!
#
# <center><img src="https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/imgs/artemis_ii_launch_events.jpg" width="700" alt="This graphic shows the time, speed, and altitude of key events from launch of the SLS (Space Launch System) rocket and Orion spacecraft and ascent to space, through Orion's perigee raise burn during the Artemis II test flight. Image credit: https://commons.wikimedia.org/wiki/File:Artemis_II_Ascent_Graphic_(Artemis_II_Mission_Trajectory_Final).jpg"/></center>
#
# ### The Journey
#
# The Orion capsule, which was attached at the top of the rocket and housed the astronauts, flew around the far side of the Moon and back in just over nine days, traveling a total distance of about 700,000 miles (about 1,100,000 km). The astronauts inside stayed busy along the way, performing many scheduled equipment tests and communicating with NASA and the press back on Earth. This diagram from NASA shows the major stages of the flight:
#
# <center><img src="https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/imgs/artemis_ii_mission_map.png" width="700" alt="This graphic shows the named stages of the Artemis II flight, from launch through splashdown. Image credit: https://www.nasa.gov/artemis-ii-press-kit/"/></center>
#
# Of course, the best part of the trip was when they reached the moon. NASA hosts a [gallery](https://www.nasa.gov/gallery/lunar-flyby/) of the stunning images the astronauts took of the Moon; here's just one sample:
#
# <center><img src="https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/imgs/earthset.jpg" width="500" alt="Earthset captured through the Orion spacecraft window at 6:41 p.m. EDT, April 6, 2026, during the Artemis II crew’s flyby of the Moon. A muted blue Earth with bright white clouds sets behind the cratered lunar surface. The dark portion of Earth is experiencing nighttime. On Earth’s day side, swirling clouds are visible over the Australia and Oceania region. In the foreground, Ohm crater has terraced edges and a flat floor interrupted by central peaks—formed when the surface rebounded upward during the impact that created the crater. Image credit: https://www.nasa.gov/image-detail/art002e009288/"/></center>
#
# ### Python Fundamentals
#
# This notebook is designed to walk you through the fundamental components of Python and incrementally apply them to construct your own visualization of the path that the Artemis II mission followed in its journey around the Moon. The data you will use to accomplish this come from real ephemeris data published by NASA, available [here](https://www.nasa.gov/missions/artemis/artemis-2/track-nasas-artemis-ii-mission-in-real-time/). This notebook uses a slightly simplified two-dimensional version of that dataset.
#
# In this demo, you will be able to practice the following Python skills:
# 1. Variable definitions and types
# 2. Lists
# 3. Loops
# 4. Plotting
#
# Let's code!

# %% [markdown]
# In addition to this crash course, you can find more comprehensive resources for learning Python at the programming language's official tutorial site (https://docs.python.org/3/tutorial/index.html), starting at Section 3.

# %% [markdown]
# ## **0. Preface**

# %% [markdown]
# ### 0.1 Reading and Running Python Code

# %% [markdown]
# Python code is evaluated in lines. When a program or piece of code is executed (i.e., run by the computer), each line is executed in sequence (unless instructed otherwise, which we will discuss later in *Section 3: Loops*).
#
# Lines of code beginning with a pound sign (#) are called **comments**. Comments are skipped when code is executed, and they allow you to write instructions or reminders in code blocks. They are especially helpful in long programs, where they are typically used to inform a reader what the program does and how the program does it. In Python, comments may also be added partway through a line, and tell the program to skip the rest of the line (so that individual lines may be annotated). Comments appear a different color than code in a Jupyter notebook.

# %% [markdown]
# In order to execute a piece of Python code within a code cell in a Jupyter notebook, hold Shift and press the Enter key while that code cell is selected. Any outputs of that code will be displayed in an output region generated just beneath the cell.
#
# For this example, we make use of Python's built-in `print()` function. The `print()` function simply outputs any values it is given. Like other functions, the values given to the `print()` function are placed between the parentheses.
#
# **Exercise:** In the cell below, if executed, the code will "print" to the display the phrase "Hello World!". Execute the code cell and confirm that it works as you expect.

# %%
# This code prints Hello World!
print("Hello World!") # This is an example of an inline comment
# Out:
# Hello World!

# %% [markdown]
# Notice that the quotation marks around the phrase "Hello World!" did *not* get output by the print statement. We'll explain why that was the case later in the following section.

# %% [markdown]
# ### 0.2 Importing Packages

# %% [markdown]
# It is generally best practice to `import` any packages you need at the start of your Python script. Packages are collections of code that other programmers have written and published for the rest of the community to use. We can `import` packages into our code to take advantage of all the functionality they add to base Python.
#
# **Exercise:** Let's import the `numpy` and `matplotlib` packages by running the following code cell.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## **1. Variables**

# %% [markdown]
# ### 1.1 Definition

# %% [markdown]
# In order for information pertaining to the execution of a program to be accessed by lines elsewhere in a program, this information needs to be stored in the memory of the computer.
#
# This information is stored in a **variable**. Variables are defined given a name (which in Python must be a sequence of alphanumeric characters and underscores beginning with a letter or underscore) and are given a value by following that name with the `=` operator.

# %% [markdown]
# **Example:**

# %%
# Define two variables
number_of_colors = 4
number_of_points = 60

# %% [markdown]
# **Exercise:** In the code block below, delete the three underscores (`___`) and try assigning a numerical value to the variable `example_variable_name`. This "blank" is used throughout this notebook to indicate locations where you should complete the provided code.

# %%
# Assign a number to this variable
example_variable_name = 12 #### Remove example value
print(example_variable_name)
# Out:
# 12

# %% [markdown]
# Certain variable names are disallowed; in particular, any variable name which matches a keyword in Python is not allowed. For reference, the list of prohibited variable names can be found at: https://www.w3schools.com/python/python_variables_names.asp.
#
# Additionally, good coding practice is to keep variable names short but descriptive &mdash; that way, they can be quickly written out and it can be easy to determine which variables correspond to what values.

# %% [markdown]
# If a value is assigned to a variable that already has a value, the new value replaces the old one.
#
# **Exercise:** Try this below by assigning a new number to `example_variable_name`.

# %%
# Assign a new number to this variable
example_variable_name = 144 #### Remove example value
print(example_variable_name)
# Out:
# 144

# %% [markdown]
# For this reason, all variable names referring to different values also need be unique.

# %% [markdown]
# ### 1.2 Types

# %% [markdown]
# Python has many built-in variable **types**. The type of a variable can be found with the function `type()`. Four simple variable types are as follows:

# %% [markdown]
# - `int`: An integer number. Unlike many other coding languages, an integer in Python can be of any length. Integers are initialized as whole numbers (e.g., `ex_variable = 1`).
# - `float`: A decimal number. For very large or very small floats, they're often abbreviated into the form `XeY`, equivalent to $X \times 10^Y$ for numbers `X` and `Y`. Floats are initialized as decimal-valued numbers (e.g., `ex_variable = 1.05`).
# - `bool`: A boolean, or a true/false value. Booleans are initialized as `True` or `False` (e.g., `ex_variable = False`).
# - `str`: A string, or a sequence of text characters. Strings are initialized as a sequence of characters surrounded by quotation marks (e.g., `ex_variable = "False"` or `ex_variable = 'Elephant'`).

# %% [markdown]
# This explains why `print("Hello World!")` above simply output `Hello World!` &mdash; the quotation marks indicated that the characters contained within were to be read as a string-type variable, and thus the value of that string was output.

# %% [markdown]
# **Example:**

# %%
# Define a string and a boolean value
name_of_cat = "Jonathan"
is_cat = True
print(type(is_cat)) # Should return <class 'bool'>
# Out:
# <class 'bool'>

# %% [markdown]
# **Exercise:** In the code block below, initialize two variables of different types and then output their types.

# %%
# Practice casting a variable to another type

#### Remove all below but print(type( and then leave the argument blank to be filled in.
first_variable = True
second_variable = 7
print(type(first_variable))
print(type(second_variable))
# Out:
# <class 'bool'>
# <class 'int'>

# %% [markdown]
# If completed correctly, you should see an output that looks like `<class 'bool'>` (using here the `bool` type as an example).
#
# In more advanced programs, you can define your own type of variable by defining a `class` (though that is well beyond the scope of this crash course).

# %% [markdown]
# ### 1.3 Operations

# %% [markdown]
# Python also has built-in support for simple **operations** between variables. These include mathematical operations (applicable to both integers and floats) and boolean operations (applicable to all types). To apply an operation between variables, simply write `a (operator) b`, where `a` and `b` are the variables or variable names in question.

# %% [markdown]
# Python supports the four classical mathematical operations: `+`, `-`, `*`, and `/`. Mathematical operations also include the modulus operator `%` (where `a % b` outputs the remainder of the division operation $a/b$), and the exponentiation operator `**` (remark: the `^` operator also exists, but is *not* an exponentiation operator).
#
# As with mathematics, parentheses indicate to Python the order in which to evaluate operations.

# %% [markdown]
# **Example:**

# %%
# Define two integers and output their product
number_of_cities = 64
people_per_city = 1_000_000 # You can include underscores in integers where commas would normally go, to make large integers easier to read
total_population = number_of_cities * people_per_city
print(total_population)
# Out:
# 64000000

# %% [markdown]
# **Exercise:** Let's practice using mathematical operations below:
# 1) Define three or more integer or float variables.
# 2) Print out the result of using two or more mathematical operations on those variables.
# 3) Confirm that the operations work as you think they should.

# %%
# Practice using mathematical operations
first_int = 50
second_int = 14
third_int = 2
print(first_int + second_int/third_int) #### Remove example operations & definitions
# Out:
# 57.0

# %% [markdown]
# Boolean operations compare the values of two variables. Boolean operators always output a boolean. They consist of the operators `==`, which returns `True` if two variables are equal and `False` otherwise, and `!=`, which returns `True` if two variables are not equal and `False` otherwise. Note that a single equal sign (`=`) is used only to assign a value to a variable, while the double equal sign (`==`) is used to check whether two quantities are equal.
#
# The boolean operators `>`, `<`, `>=`, and `<=` also exist, but they work only on variables whose values can be compared (typically just numerical variables).

# %% [markdown]
# **Example:**

# %%
# Test if one string equals another
input = "artemis_ii_mission_string"
test_string = "artemis_ii_mission_string"
print(input == test_string)
# Out:
# True

# %% [markdown]
# **Exercise:** In the code block below, test out at least three boolean operations and confirm that the work as you expect. As before, use print statements to output the results below.

# %%
# Practice using boolean operations
print(120 > 15) #### Remove example operations
print(10 == 1)
print(10 == 10)
# Out:
# True
# False
# True

# %% [markdown]
# There are other operations which exist outside the scope of this tutorial; for those, head over to the Python documentation to see a more full description. See also https://docs.python.org/3/library/stdtypes.html, which lists the full range of built-in types and operations.

# %% [markdown]
# ### 1.4 Application to Artemis II: Loading Data

# %% [markdown]
# To start visualizing the the trajectory of the Artemis II mission, we first need to load position data from the mission into a variable. The data has already been formatted in a way that is readable by existing code. To do that, we feed the `numpy` package's function `loadtxt()` the path to the input data file (https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/input-data/artemis_ii_trajectory.txt).
#
# **Exercise:** Complete the code block below to load in trajectory data from the Artemis II mission.

# %%
# Fill in the missing sections to correctly load trajectory data from the Artemis II mission
filepath = "https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/input-data/artemis_ii_trajectory.txt" #### Remove the variable name from this line but keep the url

trajectory = np.loadtxt(filepath) #### Remove the variable name trajectory

print(trajectory) #### Remove the variable name trajectory
# Out:
# [[28105.45126184  2481.71056005]
#  [28324.44735551  2658.50608626]
#  [29287.82935354  3453.82458767]
#  ...
#  [-6507.51644891 -1706.62763761]
#  [-5956.08688059 -2694.10709719]
#  [-5534.04608774 -3334.08656143]]

# %% [markdown]
# If done correctly, the output printed shows many values inside of brackets. These are a special kind of variable: lists, which act as containers holding multiple different variables. We'll talk about those next, and we'll use them to separate and read out our data from the variable we've defined above.

# %% [markdown]
# ## **2. Lists**

# %% [markdown]
# ### 2.1 Definition

# %% [markdown]
# A `list` is another fundamental way to store information in Python. As the name suggests, they are useful for organizing many individual pieces of information into one place for later reference.
#
# Python lists are rather unique: they are *mutable* (can be changed after being created), contain an *ordered* sequence of elements, and the elements can be any data type (integers, strings, floats, etc.) or a mixture of data types.
#
# Lists can be defined just like any other variable with the single equal sign operator `=`. To fill a list with **elements** at its definition call, we use square brackets `[ ]` and commas `,` to separate each element. Let's now make a list.

# %% [markdown]
# **Exercise**

# %%
# Defining a list variable
# Have the class decide to add a random string to our list!
list1 = [5, 8, "PLACEHOLDER", -22, True, 0.1, "hello", 8.25] #### Remove PLACEHOLDER

# %% [markdown]
# As mentioned above, one unique thing about Python lists is that they let you hold different data types in the same list! Lists allow us to store as many variables as we want, even other lists (this is called a *nested list*).
#
# Of course, the real usefulness of list is the user's ability to **index** them. This means that we can access any element in the list whenever we want and wherever it is in the list, without altering the list itself.
#
# To access an element from a list, we can call the name of the list variable followed by square brackets `[ ]` containing that element's **index number**.

# %% [markdown]
# **Example:**

# %%
# Get an item from the list
item1 = list1[2]
print(item1)
# Out:
# PLACEHOLDER

# %% [markdown]
# ### 2.2 Slicing Lists

# %% [markdown]
# Note that while we asked for element index 2 in the example above, it gave us the 3rd item in the list. This is normal: Python starts indexing elements with the number 0, for historical reasons. *Keep in mind, this implies that the last element in a list always has an index equal to the length of the list minus one!*
#
# We can also get multiple values at once from a list by **slicing** the list using the colon symbol `:` and two index values. Note that the ending index is not included in the slice, while the starting index *is*.

# %% [markdown]
# **Example:**

# %%
# Get a slice of a list
print(list1[3:6])
# Out:
# [-22, True, 0.1]

# %% [markdown]
# ### 2.3 Appending and Removing Elements of a List

# %% [markdown]
# The most important operation to learn here is how to add an element to an already-existing `list`. Elements can be added using the `.append()` method, which is written immediately following the variable name of a given list.

# %% [markdown]
# **Example:**

# %%
# Make a new list
list2 = [1, 2, 4, 8]
print(list2)

# Add to the list
list2.append("Sixteen")
print(list2)
# Out:
# [1, 2, 4, 8]
# [1, 2, 4, 8, 'Sixteen']

# %% [markdown]
# **Exercise:** Try appending an element to list2: it could be anything (for example, a boolean, int, float, or string). Then print the result.

# %%
# Add your own element to the list
list2.append("PLACEHOLDER")  #### Remove PLACEHOLDER

# Print the new list
print(list2)
# Out:
# [1, 2, 4, 8, 'Sixteen', 'PLACEHOLDER']

# %% [markdown]
# Elements can be removed from a list using either the `.pop()` or `.remove()` methods, which are also built in to Python. On your own time, try to remove the integer element 4 from the list we just defined using both methods to test how they work.
#
# If you are ever curious how long your list currently is, you can use the `len()` function to return its current length.

# %% [markdown]
# **Exercise:** Use the `len()` function to return the length of `list2`.

# %%
# Return the length of the list
print(len(list2)) # Fill in print statement #### Remove len(list2)
# Out:
# 6

# %% [markdown]
# This `len()` function can be used to access the end of the list, keeping in mind that you will need to subtract 1 to account for indexing starting at 0. Alternatively, you can access the final elements in any list using negative indicies, where `-1` will grab the last element, `-2` will grab the second-to-last element, and so on. Let's try this below:

# %% [markdown]
# **Example:**

# %%
print('Last element in list2:', list2[len(list2)-1], 'or', list2[-1])

print('Second-to-last element in list2:', list2[len(list2)-2], 'or', list2[-2])
# Out:
# Last element in list2: PLACEHOLDER or PLACEHOLDER
# Second-to-last element in list2: Sixteen or Sixteen

# %% [markdown]
# ### 2.4 Nested Lists

# %% [markdown]
# One of the strengths of using a `list` in Python is that it can contain variables of any type &mdash; even lists! This means that you can have nested lists of data, which is enormously helpful for saving multiple columns of data from a file. Let's define a list that contains our `list1` and `list2` variables, in addition to some other elements:

# %% [markdown]
# **Example:**

# %%
# Example of nested list:
list3 = [list1, "apple", 3.14159, list2, "pie"]

print('Length of list3:', len(list3))
print('My nested list3:', list3)
# Out:
# Length of list3: 5
# My nested list3: [[5, 8, 'PLACEHOLDER', -22, True, 0.1, 'hello', 8.25], 'apple', 3.14159, [1, 2, 4, 8, 'Sixteen', 'PLACEHOLDER'], 'pie']

# %% [markdown]
# We can see that our `len()` function returned the number of elements or rows in our nested list, which represent the first layer of data. To access each element or row in this 2-layered nested list, we can therefore use the same indexing notation as before:

# %% [markdown]
# **Example:**

# %%
print("Each element in list3:")
print(list3[0])
print(list3[1])
print(list3[2])
print(list3[3])
print(list3[4])
# Out:
# Each element in list3:
# [5, 8, 'PLACEHOLDER', -22, True, 0.1, 'hello', 8.25]
# apple
# 3.14159
# [1, 2, 4, 8, 'Sixteen', 'PLACEHOLDER']
# pie

# %% [markdown]
# But what if we want to access the individual elements in our nested lists within `list3`? For each layer in `list3`, all we need to do is tack on an extra set of brackets `[]` in our indexing, like so:

# %% [markdown]
# **Example:**

# %%
print("Element #1 in list3:", list3[0])
print("Element #1 of this nested list within list3:", list3[0][0])
# Out:
# Element #1 in list3: [5, 8, 'PLACEHOLDER', -22, True, 0.1, 'hello', 8.25]
# Element #1 of this nested list within list3: 5

# %% [markdown]
# **Exercise:** Practice nested list indexing on the other nested list!

# %%
print("Element #4 in list3:", list3[3]) # Add your code here #### Remove index
print("Element #2 of this nested list within list3:", list3[3][1]) # Add your code here #### Remove indices
# Out:
# Element #4 in list3: [1, 2, 4, 8, 'Sixteen', 'PLACEHOLDER']
# Element #2 of this nested list within list3: 2

# %% [markdown]
# Nested lists and indexing are incredibly powerful for data analysis, as most data formats you will work with have at least two layers (rows and columns).

# %% [markdown]
# ### 2.5 Application to Artemis II: Exploring the Data and Practicing Double-Indexing

# %% [markdown]
# Now that we have a better understanding of lists, we can begin to work with the Artemis II trajectory data that we previously imported. As a reminder, these data look like so:

# %%
# Redefining just in case
filepath = "https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/input-data/artemis_ii_trajectory.txt"
trajectory = np.loadtxt(filepath)
print(trajectory)
# Out:
# [[28105.45126184  2481.71056005]
#  [28324.44735551  2658.50608626]
#  [29287.82935354  3453.82458767]
#  ...
#  [-6507.51644891 -1706.62763761]
#  [-5956.08688059 -2694.10709719]
#  [-5534.04608774 -3334.08656143]]

# %% [markdown]
# The `trajectory` variable contains every recorded position of the Artemis II spacecraft, where each row holds two values: the **x-coordinate** (column 0) and the **y-coordinate** (column 1) of the spacecraft, measured in kilometers from Earth's center.
#
# Let's begin by exploring the structure of our data:

# %% [markdown]
# **Example:**

# %%
# How many position measurements are in the file? 
print("Number of data points:", len(trajectory))
# Out:
# Number of data points: 3259

# %% [markdown]
# **Example:**

# %%
# What do the first few rows look like? 
print("First 3 positions:\n", trajectory[0:3])
# Out:
# First 3 positions:
#  [[28105.45126184  2481.71056005]
#  [28324.44735551  2658.50608626]
#  [29287.82935354  3453.82458767]]

# %% [markdown]
# Each element of `trajectory` is itself a two-element list, just like the nested lists we saw above! We can therefore use **double-indexing** to pull out a single coordinate: `trajectory[row][column]`, where column `0` is x and column `1` is y.
#
# <center><img src="https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/imgs/artemis_ii_double_indexing.png" width="800" alt="Annotated double indexing infographic"></center>

# %% [markdown]
# **Exercise:** Let's practice double-indexing by separating the x- and y-coordinates of the first three data points into their own lists.

# %%
# Separate x- and y-coordinates for the first 3 data points
x_coords = []
x_coords.append(trajectory[0][0])  # x-coordinate of Artemis II position 0
x_coords.append(trajectory[1][0])  # x-coordinate of Artemis II position 1 #### Remove both indices
x_coords.append(trajectory[2][0])  # x-coordinate of Artemis II position 2 #### Remove both indices

y_coords = []
y_coords.append(trajectory[0][1])  # y-coordinate of Artemis II position 0
y_coords.append(trajectory[1][1])  #### Remove both indices
y_coords.append(trajectory[2][1])  #### Remove both indices

print("x-coordinates (km):", x_coords)
print("y-coordinates (km):", y_coords)
# Out:
# x-coordinates (km): [np.float64(28105.45126183836), np.float64(28324.447355506778), np.float64(29287.82935353761)]
# y-coordinates (km): [np.float64(2481.710560046734), np.float64(2658.506086256654), np.float64(3453.824587665072)]

# %% [markdown]
# As we saw, there are over 3,000 data points in this trajectory dataset. Appending all the x- and y-coordinates to separate lists would take a long time and would be incredibly inefficient. If only there was a way to automate iterating through lists in Python...

# %% [markdown]
# ## **3. Loops**

# %% [markdown]
# ### 3.1 `for` loops

# %% [markdown]
# Often when coding in Python, we want to apply the same operation to every item in a list. We could do this one at a time, as we started to demonstrate above, but what if our list has a million numbers in it? We don't want to type out a million lines of code! This is where **loops** come in handy. The most common type of loop in Python is the `for` loop. Here's an example of how it works:

# %% [markdown]
# **Example:**

# %%
# Print out every item in list1, the sample list we made earlier
for item in list1:
    print(item)
# Out:
# 5
# 8
# PLACEHOLDER
# -22
# True
# 0.1
# hello
# 8.25

# %% [markdown]
# `for` loops have several important features:
#
# - They must start with the keyword `for`.
# - After `for` comes the name of a temporary variable. Each item in the list you iterate over is temporarily stored in this variable while the operations inside the `for` loop are applied to it.
# - Next is the keyword `in`, followed by the name of the list you want to iterate over, and then a colon `:`.
# - The operations you want to apply to each item in the list come next, and they must all be indented with a `tab`. This way, Python recognizes that they're part of the `for` loop.
#
# We can also easly access the index of each item in a list while using a `for` loop by using the `range()` and `len()` functions.

# %% [markdown]
# **Example:**

# %%
letters = ['a', 'b', 'c', 'd', 'e']

for i in range(len(letters)):
	print(letters[i])
# Out:
# a
# b
# c
# d
# e

# %% [markdown]
# **Exercise:** Use the `for i in range(len(...))` construction to print out every item in `list1` and the index at which it appears.

# %%
# Print out every item in list1 and its index
for i in range(len(list1)):
    print(list1[i], 'is at index', i) #### Remove list1[i] and i
# Out:
# 5 is at index 0
# 8 is at index 1
# PLACEHOLDER is at index 2
# -22 is at index 3
# True is at index 4
# 0.1 is at index 5
# hello is at index 6
# 8.25 is at index 7

# %% [markdown]
# The built-in `range()` function can be used to quickly make a list of many values. This function takes in three numbers (start, end, step size), which it uses to define a `list`, but only the end argument is required (it will assume to start at 0 since indexing starts at 0, and use a step size of 1). As above, this function can be used to iterate over the indices of a list, instead of directly iterating over its elements. This is generally a safer and more powerful way to write `for` loops as it allows us to potentially index multiple lists of the same length in a single iteration and perform operations between their elements.

# %% [markdown]
# ### 3.2 Application to Artemis II: Separating the x- and y-Coordinates into Individual Lists

# %% [markdown]
# **Exercise:** Practice using a `for` loop to separate our x- and y-coordinates into lists.

# %%
# Create empty lists for x- and y-coordinates
# Note that these lists have the same names as the ones we defined in Section 2.5
# This will overwrite the information we stored there, but that's okay!
x_coords = []
y_coords = []

# For every data point in the "trajectory" array, append the x- and y-coordinate to the appropriate list
for i in range(len(trajectory)):  #### Remove i and range(len(trajectory))
    x_coords.append(trajectory[i][0])  #### Remove trajectory[i][0]
    y_coords.append(trajectory[i][1])  #### Remove trajectory[i][1]

# %% [markdown]
# ## **4. Plotting**

# %% [markdown]
# ### 4.1 Making a Simple Plot

# %% [markdown]
# So far, we've used **loops** to manipulate our **lists** of data so we can draw conclusions and better understand the **variables** we're working with. What if we want to represent these data visually? Python and its associated packages are particularly well-suited for plotting appealing, digestable graphs.
#
# The two most important packages necessary for creating plots in Python are ***Matplotlib*** and its submodule ***Pyplot*** (which streamlines many of the capabilities of Matplotlib). Both packages offer a wide variety of options for customizing your graph once you write the proper code. Once you're familiar with the basics of Matplotlib and Pyplot, feel free to peruse these packages' websites (often referred to as the "documentation"): [Matplotlib](https://matplotlib.org/); [Pyplot](https://matplotlib.org/stable/api/pyplot_summary.html).
#
# **Exercise:** Let's generate a basic scatterplot of cubed numbers. Recall that we imported Matplotlib as `matplotlib` and Pyplot as `plt`. We'll use the `scatter` function in Pyplot to graph our numbers on the x-axis and our cubed numbers on the y-axis.

# %%
# For simplicity, let's name each list for its corresponding axis.
x = [1, 2, 3, 4, 5]
y = []
for num in x:
    y.append(num**3)

# The "scatter" function is housed under the matplotlib.pyplot module, which we imported as "plt".
# So, we use this function like so:
plt.scatter(x, y) #### Remove x and y
# The first two arguments of the function are the lists that contain the data to be plotted on the x- and y-axes!

plt.show()
# Whenever we use a function in Matplotlib that generates a plot,
# we use plt.show() to tell the computer to print our resulting graph.

# %% [markdown]
# ### 4.2 Adding Descriptive Features to a Plot

# %% [markdown]
# Great! Now we have a simple plot that traces the $y=x^3$ function we would expect from our inputted data. However, this plot is missing some key features: a title and axis labels. These can be generated using Matplotlib functions, too! We can also adjust some aesthetic components, such as the point shape, color, and size, to our liking.
#
# `matplotlib` has many built-in colors and nearly infinite capacity to produce custom colors. Here's a list of the pre-loaded keyword colors:
#
# <center><img src="https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/imgs/matplotlib_named_colors.png" width="700" alt="matplotlib keyword colors"></center>

# %% [markdown]
# **Exercise:** Let's replot our sample data using the same `scatter()` function, adding several descriptive elements. Fill in a color from the list above in the `c` argument of the `scatter()` function.

# %%
# Add your code here:
plt.scatter(x, y, s=200, c='firebrick', marker="x") #### Remove 'firebrick'
# Here, the "s" argument sets the size of the data points,
# the "c" argument sets the color of the points, and the "marker" argument sets the shape of the points.
# See the Matplotlib documentation for more options regarding customization, including color and marker options.

# We add plot title and axis label commands under the plt.scatter() function and before plt.show().

# Axis labels
plt.xlabel("Numbers") # Notice we use strings as our input.
plt.ylabel("Numbers Cubed")

# Plot title
plt.title("Positive Integers Cubed") # Notice we use strings as our input.

plt.show()

# %% [markdown]
# Nice &mdash; now we have a clear title for our plot and axis labels. These are very important features when creating a graph to communicate data.

# %% [markdown]
# ### 4.3 Application to Artemis II: Plotting the Mission's Trajectory around the Moon

# %% [markdown]
# Finally, we can combine all we've learned to plot the Artemis II mission's trajectory around the Moon! We'll use a different plotting function this time: `plt.plot()`. While `plt.scatter()` plots the data we input as discrete points, `plt.plot()` connects our data points with line segments.

# %% [markdown]
# **Exercise:** In the cell below, fill in three missing elements required to plot the mission's trajectory:
# 1. Fill in the names of the lists in which we stored the x- and y-coordinates of the Orion capsule in Section 3.2.
# 2. Choose a color for the plotted data. Note that `plt.plot()` uses a different name for its color argument than `plt.scatter()`!
# 3. Give the plot axis labels.

# %%
# Create the figure -- we didn't include this function before, but it allows us to set the figure size
plt.figure(figsize=(6, 6))

# Plot the x- and y-coordinates of the mission's trajectory
plt.plot(x_coords, y_coords, color='firebrick') #### Remove x_coords, y_coords, and 'firebrick'

# Set the title, axis labels, and font sizes
plt.title('Artemis II Mission Trajectory', size=15)
plt.xlabel('x (km)', size=15) #### Remove 'x (km)'
plt.ylabel('y (km)', size=15) #### Remove 'y (km)'

# Force both axes to use the same scale
plt.gca().set_aspect('equal')

plt.show()

# %% [markdown]
# Excellent! Now we have a plot that shows the path the Orion capsule followed in its journey around the Moon and back. We can start to identify some key features of the trip, like where Orion separated from the rocket that carried it to outer space (also called USS, or "upper stage separation"), the long flight to the Moon, the brief loop around the Moon, and where Orion re-entered Earth's atmosphere (also called EI, or "entry interface").
#
# We can use some of `matplotlib`'s tools to make a higher-quality plot that highlights some of these features. Let's implement the following changes to our plotting code:
# - Change the dpi ("dots per inch," or resolution) of the figure
# - Change the font of the title and axis labels
# - Change the background color
# - Change the color and line style of Orion's path (see [this page](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html) of the `matplotlib` documentation for more about line styles)
# - Set the x- and y-axis limits
# - Add to-scale representations of the Earth and the Moon
# - Add annotations to the plot
# - Save the figure to a file
#
# Note that there's no missing code to fill in below. You've done the hard work of learning Python; now run this last cell and enjoy the results!

# %%
# Import a few more packages
from PIL import Image
from urllib.request import urlopen

# Set the dpi ("dots per inch," or resolution) of the figure
matplotlib.rcParams['figure.dpi'] = 100
# Change the font style
plt.rcParams['font.family'] = 'serif'
# Set the background to be black and the axes and text to be white
plt.style.use('dark_background')

# Create the figure
plt.figure(figsize=(8, 8))

# Plot the x- and y-coordinates of the mission's trajectory
plt.plot(x_coords, y_coords, color='lightcyan', linestyle=(3, (10, 2)))

# Set axis limits
plt.xlim(-49_000, 349_000)
plt.ylim(-40_000, 315_000)

# Set the title, axis labels, and font sizes
plt.title('Artemis II Mission Trajectory', size=15)
plt.xlabel('x (km)', size=15)
plt.ylabel('y (km)', size=15)

# Add to-scale representations of the Earth and the Moon
earth_img_url = 'https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/imgs/earth.png'
earth_img = np.array(Image.open(urlopen(earth_img_url)))
r_e = 6_371 # Earth radius in km, from https://en.wikipedia.org/wiki/Earth_radius
plt.imshow(earth_img, extent=(-r_e, r_e, -r_e, r_e))

moon_img_url = 'https://raw.githubusercontent.com/pyiu-workshops/pyiu/refs/heads/main/crash-course/artemis-ii/imgs/moon.png'
moon_img = np.array(Image.open(urlopen(moon_img_url)))
r_m = 1_737 # Moon radius in km, from https://en.wikipedia.org/wiki/Moon
m_l = (286_900, 291_500) # Approximate Moon location in km
plt.imshow(moon_img, extent=(m_l[0] - r_m, m_l[0] + r_m, m_l[1] - r_m, m_l[1] + r_m))

# --- Add annotations to the plot ---
# Upper State Separation (USS)
plt.scatter(x_coords[0], y_coords[0], c='C0', s=100)
plt.annotate('USS', xy=(10_000, 12_000), xycoords='data', size=12, color='C0')

# Translunar Injection (TLI) Burn
plt.scatter(x_coords[355], y_coords[355], c='C1', s=100)
plt.annotate('TLI', xy=(15_000, -22_000), xycoords='data', size=12, color='C1')

# Lunar flyby
plt.annotate('Lunar\nFlyby', xy=(x_coords[1_797] + 2_000, y_coords[1_797]), xytext=(310_000, 270_000), xycoords='data',
			 size=12, color='C2', arrowprops={'arrowstyle':'fancy', 'relpos':(0, 0.75), 'color':'C2'})

# Return Trajectory Correction (RTC) Burn 1
plt.scatter(x_coords[2_173], y_coords[2_173], c='C3', s=100)
plt.annotate('RTC 1', xy=(216_000, 272_000), xycoords='data', size=12, color='C3')

# RTC Burn 2
plt.scatter(x_coords[2_940], y_coords[2_940], c='C4', s=100)
plt.annotate('RTC 2', xy=(67_000, 162_000), xycoords='data', size=12, color='C4')

# RTC Burn 3
plt.scatter(x_coords[3_180], y_coords[3_180], c='C5', s=100)
plt.annotate('RTC 3', xy=(-15_000, 75_000), xycoords='data', size=12, color='C5')

# Entry Interface (EI)
plt.annotate('EI', xy=(x_coords[-1], y_coords[-1]), xytext=(-35_000, -25_000), xycoords='data', size=12, color='C6',
			 arrowprops={'arrowstyle':'fancy', 'relpos':(1, 1), 'color':'C6'})
# -----------------------------------

# Save the figure as a .png file
plt.savefig('artemis_ii_trajectory.png')
# Show the plot
plt.show()

# Change style settings back to normal
plt.style.use('default')

# Image Credits
# Earth: https://commons.wikimedia.org/wiki/File:The_Earth_seen_from_Apollo_17_with_transparent_background.png
# Moon: https://toppng.com/show_download/170855/moon-transparent-png-full-moon

# %% [markdown]
# Et viola! We have a high-quality visualization of the path the Orion capsule followed on its journey around the Moon during the Artemis II mission.
#
# Here's some more detail about the various terms NASA uses to describe the phases of the mission:
# - **USS:** Short for **"Upper Stage Separation,"** this is the point where the Orion capsule separated from the second stage of the rocket that carried it out of Earth's atmosphere. Our dataset begins here.
# - **TLI:** Short for **"Translunar Injection,"** this is the point where Orion's main thruster fired, boosting the capsule out of Earth's orbit and onto a path that would intercept the Moon's orbit. This 5-minute, 49-second burn consumed about 1,000 pounds of fuel.
# - **Lunar Flyby:** The point of closest approach to the Moon. The Artemis II astronauts came within about 4,067 miles (6,545 km) of the Moon's surface.
# - **RTC 1/2/3:** Short for **"Return Trajectory Correction,"** these three points mark where Orion fired its thrusters for a few seconds to make slight corrections to its trajectory, ensuring it would intercept Earth's orbit exactly as planned.
# - **EI:** Short for **"Entry Interface,"** this is the point where Orion re-entered Earth's atmosphere. Our dataset ends here.
#
# Plot customization in Python is virtually limitless &mdash; read through the [matplotlib cheat sheets and handouts](https://matplotlib.org/cheatsheets/) to get a grasp on all the most common tools, and explore the official documentation to learn more.
#
# Also note that when working in Colab, using `plt.savefig()` isn't enough to save the figure to your computer &mdash; it's currently only saved temporarily to Google's servers. You will need to explicitly download it: navigate to the **Files** tab on the left-hand side, click on the three vertical dots that show up next to your .png file, and press "Download."
#
# Thanks for participating in our Python Crash Course! For more demos and Python resources, visit [our GitHub](https://github.com/pyiu-workshops/pyiu) or email us at pyiu.bloomington@gmail.com.
